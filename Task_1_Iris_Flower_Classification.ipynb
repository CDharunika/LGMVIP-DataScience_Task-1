# %% [markdown]
# # **LGMVIP_July_Data Science Internship task-1**
# **Iris Flower classification**
#
# Building a ML model

# %% [markdown]
# **Importing neccessary libraries**

# %%
import pandas as pd
import numpy as np
#to plot graph
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics as met
#train test split
from sklearn.model_selection import train_test_split
#model
from sklearn.linear_model import LogisticRegression
#evaluation
from sklearn.metrics import accuracy_score

# %% [markdown]
# **Importing dataset**

# %%
dataset=pd.read_csv('/content/drive/MyDrive/IRIS.csv')

# %% [markdown]
# **Exploring the dataset**

# %%
dataset
# Out:
#      sepal_lengthCm  sepal_widthCm  petal_lengthCm  petal_widthCm  \
# 0               5.1            3.5             1.4            0.2
# 1               4.9            3.0             1.4            0.2
# 2               4.7            3.2             1.3            0.2
# 3               4.6            3.1             1.5            0.2
# 4               5.0            3.6             1.4            0.2
# ..              ...            ...             ...            ...
# 145             6.7            3.0             5.2            2.3
# 146             6.3            2.5             5.0            1.9
# 147             6.5            3.0             5.2            2.0
# 148             6.2            3.4             5.4            2.3
# 149             5.9            3.0             5.1            1.8
#
#             species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# ...

# %%
dataset.head()
# Out:
#    sepal_lengthCm  sepal_widthCm  petal_lengthCm  petal_widthCm      species
# 0             5.1            3.5             1.4            0.2  Iris-setosa
# 1             4.9            3.0             1.4            0.2  Iris-setosa
# 2             4.7            3.2             1.3            0.2  Iris-setosa
# 3             4.6            3.1             1.5            0.2  Iris-setosa
# 4             5.0            3.6             1.4            0.2  Iris-setosa

# %%
dataset.tail()
# Out:
#      sepal_lengthCm  sepal_widthCm  petal_lengthCm  petal_widthCm  \
# 145             6.7            3.0             5.2            2.3
# 146             6.3            2.5             5.0            1.9
# 147             6.5            3.0             5.2            2.0
# 148             6.2            3.4             5.4            2.3
# 149             5.9            3.0             5.1            1.8
#
#             species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
dataset.shape
# Out:
# (150, 5)

# %%
dataset.info
# Out:
# <bound method DataFrame.info of      sepal_lengthCm  sepal_widthCm  petal_lengthCm  petal_widthCm  \
# 0               5.1            3.5             1.4            0.2
# 1               4.9            3.0             1.4            0.2
# 2               4.7            3.2             1.3            0.2
# 3               4.6            3.1             1.5            0.2
# 4               5.0            3.6             1.4            0.2
# ..              ...            ...             ...            ...
# 145             6.7            3.0             5.2            2.3
# 146             6.3            2.5             5.0            1.9
# 147             6.5            3.0             5.2            2.0
# 148             6.2            3.4             5.4            2.3
# 149             5.9            3.0             5.1            1.8
#
#             species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
dataset.describe()
# Out:
#        sepal_lengthCm  sepal_widthCm  petal_lengthCm  petal_widthCm
# count      150.000000     150.000000      150.000000     150.000000
# mean         5.843333       3.054000        3.758667       1.198667
# std          0.828066       0.433594        1.764420       0.763161
# min          4.300000       2.000000        1.000000       0.100000
# 25%          5.100000       2.800000        1.600000       0.300000
# 50%          5.800000       3.000000        4.350000       1.300000
# 75%          6.400000       3.300000        5.100000       1.800000
# max          7.900000       4.400000        6.900000       2.500000

# %%
dataset.corr()
# Out:
# <ipython-input-10-c187c74d1e71>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataset.corr()
#                 sepal_lengthCm  sepal_widthCm  petal_lengthCm  petal_widthCm
# sepal_lengthCm        1.000000      -0.109369        0.871754       0.817954
# sepal_widthCm        -0.109369       1.000000       -0.420516      -0.356544
# petal_lengthCm        0.871754      -0.420516        1.000000       0.962757
# petal_widthCm         0.817954      -0.356544        0.962757       1.000000

# %%
dataset.cov()
# Out:
# <ipython-input-12-418ba3616d2e>:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataset.cov()
#                 sepal_lengthCm  sepal_widthCm  petal_lengthCm  petal_widthCm
# sepal_lengthCm        0.685694      -0.039268        1.273682       0.516904
# sepal_widthCm        -0.039268       0.188004       -0.321713      -0.117981
# petal_lengthCm        1.273682      -0.321713        3.113179       1.296387
# petal_widthCm         0.516904      -0.117981        1.296387       0.582414

# %%
dataset.nunique()
# Out:
# sepal_lengthCm    35
# sepal_widthCm     23
# petal_lengthCm    43
# petal_widthCm     22
# species            3
# dtype: int64

# %%
dataset.isnull().sum()
# Out:
# sepal_lengthCm    0
# sepal_widthCm     0
# petal_lengthCm    0
# petal_widthCm     0
# species           0
# dtype: int64

# %%
dataset.dtypes
# Out:
# sepal_lengthCm    float64
# sepal_widthCm     float64
# petal_lengthCm    float64
# petal_widthCm     float64
# species            object
# dtype: object

# %%
d=dataset.groupby('species')
d.head()
# Out:
#      sepal_lengthCm  sepal_widthCm  petal_lengthCm  petal_widthCm  \
# 0               5.1            3.5             1.4            0.2
# 1               4.9            3.0             1.4            0.2
# 2               4.7            3.2             1.3            0.2
# 3               4.6            3.1             1.5            0.2
# 4               5.0            3.6             1.4            0.2
# 50              7.0            3.2             4.7            1.4
# 51              6.4            3.2             4.5            1.5
# 52              6.9            3.1             4.9            1.5
# 53              5.5            2.3             4.0            1.3
# 54              6.5            2.8             4.6            1.5
# 100             6.3            3.3             6.0            2.5
# 101             5.8            2.7             5.1            1.9
# 102             7.1            3.0             5.9            2.1
# ...

# %%
dataset['species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# **Data Visualization**

# %% [markdown]
# **Histogram, BoxPlot, ScatterPlot - 	sepal_lengthCm,	sepal_widthCm,	petal_lengthCm,	petal_widthCm**

# %%
plt.hist(dataset['sepal_lengthCm'], bins=10)
plt.xlabel('sepal_lengthCm')
plt.ylabel('count')
plt.title('Histogram of sepal_length in Iris')
plt.show()

print(dataset['sepal_lengthCm'].describe())
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: sepal_lengthCm, dtype: float64

# %%
plt.hist(dataset['sepal_widthCm'], bins=10)
plt.xlabel('Sepal_widthCm')
plt.ylabel('count')
plt.title('Histogram of Sepal_Width in Iris')
plt.show()

print(dataset['sepal_widthCm'].describe())
# Out:
# count    150.000000
# mean       3.054000
# std        0.433594
# min        2.000000
# 25%        2.800000
# 50%        3.000000
# 75%        3.300000
# max        4.400000
# Name: sepal_widthCm, dtype: float64

# %%
plt.hist(dataset['petal_lengthCm'], bins=10)
plt.xlabel('petal_lengthCm')
plt.ylabel('count')
plt.title('Histogram of PetalLength in Iris')
plt.show()

print(dataset['petal_lengthCm'].describe())
# Out:
# count    150.000000
# mean       3.758667
# std        1.764420
# min        1.000000
# 25%        1.600000
# 50%        4.350000
# 75%        5.100000
# max        6.900000
# Name: petal_lengthCm, dtype: float64

# %%
plt.hist(dataset['petal_widthCm'], bins=10)
plt.xlabel('PetalWidthCm')
plt.ylabel('count')
plt.title('Histogram of PetalWidth in Iris')
plt.show()

print(dataset['petal_widthCm'].describe())
# Out:
# count    150.000000
# mean       1.198667
# std        0.763161
# min        0.100000
# 25%        0.300000
# 50%        1.300000
# 75%        1.800000
# max        2.500000
# Name: petal_widthCm, dtype: float64

# %%
sns.scatterplot(x='sepal_lengthCm',y='petal_lengthCm',hue='species',style='species',data=dataset )
plt.show()

# %%
sns.set_style("whitegrid")
sns.boxplot(x = 'species', y = 'sepal_lengthCm', data=dataset)
# Out:
# <Axes: xlabel='species', ylabel='sepal_lengthCm'>

# %%
plt.figure(figsize=(5,5))
sns.heatmap(dataset.corr())
# Out:
# <ipython-input-26-db357c7660ba>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(dataset.corr())
# <Axes: >

# %% [markdown]
# **Data** **Clustering**

# %%
mapping = {'Iris-setosa': 0, 'Iris-versicolor': 1, 'Iris-virginica': 2}

# Apply the mapping to the 'Species' column
dataset['species_category'] = dataset['species'].map(mapping)

# Print the resulting DataFrame
dataset.head()
# Out:
#    sepal_lengthCm  sepal_widthCm  petal_lengthCm  petal_widthCm      species  \
# 0             5.1            3.5             1.4            0.2  Iris-setosa
# 1             4.9            3.0             1.4            0.2  Iris-setosa
# 2             4.7            3.2             1.3            0.2  Iris-setosa
# 3             4.6            3.1             1.5            0.2  Iris-setosa
# 4             5.0            3.6             1.4            0.2  Iris-setosa
#
#    species_category
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %%
dataset.tail()
# Out:
#      sepal_lengthCm  sepal_widthCm  petal_lengthCm  petal_widthCm  \
# 145             6.7            3.0             5.2            2.3
# 146             6.3            2.5             5.0            1.9
# 147             6.5            3.0             5.2            2.0
# 148             6.2            3.4             5.4            2.3
# 149             5.9            3.0             5.1            1.8
#
#             species  species_category
# 145  Iris-virginica                 2
# 146  Iris-virginica                 2
# 147  Iris-virginica                 2
# 148  Iris-virginica                 2
# 149  Iris-virginica                 2

# %%
X= dataset[['sepal_lengthCm','sepal_widthCm','petal_lengthCm','petal_widthCm']]
Y= dataset['species']

# %%
X
# Out:
#      sepal_lengthCm  sepal_widthCm  petal_lengthCm  petal_widthCm
# 0               5.1            3.5             1.4            0.2
# 1               4.9            3.0             1.4            0.2
# 2               4.7            3.2             1.3            0.2
# 3               4.6            3.1             1.5            0.2
# 4               5.0            3.6             1.4            0.2
# ..              ...            ...             ...            ...
# 145             6.7            3.0             5.2            2.3
# 146             6.3            2.5             5.0            1.9
# 147             6.5            3.0             5.2            2.0
# 148             6.2            3.4             5.4            2.3
# 149             5.9            3.0             5.1            1.8
#
# [150 rows x 4 columns]

# %%
Y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: species, Length: 150, dtype: object

# %% [markdown]
# **Test/train split**

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.20,random_state=42)

# %% [markdown]
# **Training with the logistic regression model**

# %%
#creatING an instance for the LogisticRegression model
lr = LogisticRegression()
lr.fit(X,Y)

# Train the model with the training set
lr.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
predictions = lr.predict(X)

# Comparing with the actual charges
Scores = pd.DataFrame({'Actual':Y,'Predictions':predictions})
Scores.head()
# Out:
#         Actual  Predictions
# 0  Iris-setosa  Iris-setosa
# 1  Iris-setosa  Iris-setosa
# 2  Iris-setosa  Iris-setosa
# 3  Iris-setosa  Iris-setosa
# 4  Iris-setosa  Iris-setosa

# %%
#making predicions
Y_test_hat=lr.predict(X_test)
#Evolution of model
print('ACCURACY SCORE: ',accuracy_score(Y_test,Y_test_hat)*100,'%')
# Out:
# ACCURACY SCORE:  100.0 %

# %% [markdown]
# IT IS CLEAR THAT LOGISTIC REGRESSION GIVES 100% ACCURACY
